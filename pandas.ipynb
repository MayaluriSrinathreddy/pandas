# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\mayaluri nani\Downloads\1940599-loandata - Copy\loandata.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
##info it will give the how many null values and how many which data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
## unique it will give unique values

df["Gender"].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
## n unique it will give how many unique values
df["Gender"].nunique()
# Out:
# 2

# %%
## value it will give the value counts
df["Gender"].value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
### to accesing the columns
###df["col name"]
df["Gender"]
# Out:
# 0        Male
# 1      Female
# 2      Female
# 3      Female
# 4         NaN
#         ...
# 609      Male
# 610      Male
# 611       NaN
# 612      Male
# 613      Male
# Name: Gender, Length: 614, dtype: object

# %%
### if you want to acces multiple columns
##df[["col name"]]
df[["Gender","Married"]]
# Out:
#      Gender Married
# 0      Male     Yes
# 1    Female     Yes
# 2    Female      No
# 3    Female      No
# 4       NaN     Yes
# ..      ...     ...
# 609    Male     Yes
# 610    Male     Yes
# 611     NaN     Yes
# 612    Male     Yes
# 613    Male     Yes
#
# [614 rows x 2 columns]

# %%
## how to accesing the rows
##loc----location
###iloc---index location
df.loc[3]
# Out:
# Loan_ID              LP002603
# Gender                 Female
# Married                    No
# Dependents                  0
# Education            Graduate
# Self_Employed              No
# ApplicantIncome           645
# CoapplicantIncome      3683.0
# LoanAmount              113.0
# Loan_Amount_Term        480.0
# Credit_History            1.0
# Property_Area           Rural
# Loan_Status                 Y
# Name: 3, dtype: object

# %%
##if you want multiple rows
df.loc[[3,4,5]]
# Out:
#     Loan_ID  Gender Married Dependents Education Self_Employed  \
# 3  LP002603  Female      No          0  Graduate            No
# 4  LP001644     NaN     Yes          0  Graduate           Yes
# 5  LP001259    Male     Yes          1  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
# 5             1000             3022.0       110.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 3             1.0         Rural           Y
# 4             1.0         Rural           Y
# 5             1.0         Urban           N

# %%
### if you want only some columns
###df(rows,columns)
df.loc[1:4,["Gender","Dependents"]]
# Out:
#    Gender Dependents
# 1  Female          2
# 2  Female         3+
# 3  Female          0
# 4     NaN          0

# %%
df.iloc[1:6,:]
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
# 5  LP001259    Male     Yes          1      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
# 5             1000             3022.0       110.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 1             1.0     Semiurban           Y
# 2             NaN         Urban           N
# ...

# %%
df.iloc[1:6,1:3]
# Out:
#    Gender Married
# 1  Female     Yes
# 2  Female      No
# 3  Female      No
# 4     NaN     Yes
# 5    Male     Yes

# %%
##head it will give first five columns
##tail it will give last five columns
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...

# %%
df.tail()
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 609  LP001640   Male     Yes          0  Graduate           Yes
# 610  LP001536   Male     Yes         3+  Graduate            No
# 611  LP001585    NaN     Yes         3+  Graduate            No
# 612  LP002101   Male     Yes          0  Graduate           NaN
# 613  LP002317   Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609            39147             4750.0       120.0             360.0
# 610            39999                0.0       600.0             180.0
# 611            51763                0.0       700.0             300.0
# 612            63337                0.0       490.0             180.0
# 613            81000                0.0       360.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0     Semiurban           Y
# 610             0.0     Semiurban           Y
# ...

# %%
##describe it will give numerical values
##describe(include="object")it will give categarical values
### describe (include="all") it will give both categiraicl and numerical values
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.describe(include="object")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001722   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
#
#        Property_Area Loan_Status
# count            614         614
# unique             3           2
# top        Semiurban           Y
# freq             233         422

# %%
df.describe(include="all")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001722   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  592.000000         600.00000
# ...

# %%
##type casting
## how to change the  data tpe
##df["col name"]=df["col name"],astype("---")
df["CoapplicantIncome"]=df["CoapplicantIncome"].astype("int")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
## how to change the column name
## df.rename(columns={"col name":"new col name"})
### inpace=True is used to change the original column by default
df.rename(columns={"Self_Employed":"Selfemployed"},inplace=True)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644     NaN     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 609  LP001640    Male     Yes          0      Graduate          Yes
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585     NaN     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
### sorting
### df.sort_indexing()
### df.sort_values ---to sort the column name
df.sort_index()
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644     NaN     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 609  LP001640    Male     Yes          0      Graduate          Yes
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585     NaN     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
df.sort_index(ascending=False)
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 613  LP002317    Male     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 611  LP001585     NaN     Yes         3+      Graduate           No
# 610  LP001536    Male     Yes         3+      Graduate           No
# 609  LP001640    Male     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 4    LP001644     NaN     Yes          0      Graduate          Yes
# 3    LP002603  Female      No          0      Graduate           No
# 2    LP002949  Female      No         3+      Graduate          NaN
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 0    LP001722    Male     Yes          0      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 613            81000                  0       360.0             360.0
# ...

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644     NaN     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 609  LP001640    Male     Yes          0      Graduate          Yes
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585     NaN     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
df.sort_values("ApplicantIncome")
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644     NaN     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 609  LP001640    Male     Yes          0      Graduate          Yes
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585     NaN     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
### to sort multiple columns columns
df.sort_values(["ApplicantIncome","CoapplicantIncome"])
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644     NaN     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 609  LP001640    Male     Yes          0      Graduate          Yes
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585     NaN     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
## add columns
## df["col name"]=values
df["location"]="hyd"

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644     NaN     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 609  LP001640    Male     Yes          0      Graduate          Yes
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585     NaN     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
df["values"]=list(range(0,614))

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644     NaN     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 609  LP001640    Male     Yes          0      Graduate          Yes
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585     NaN     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
## to add the rows
##df.loc["no"]=values
df.loc[614]=["lp090","male","yes","3+","gradute","no",18899,0,89.0,360.0,0.0,"rural","N","hyd",671]

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644     NaN     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585     NaN     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
# 614     lp090    male     yes         3+       gradute           no
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
### how to delte the columns and rows
df.drop(['location',],axis=1)
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644     NaN     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585     NaN     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
# 614     lp090    male     yes         3+       gradute           no
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644     NaN     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585     NaN     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
# 614     lp090    male     yes         3+       gradute           no
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
### to delete multiple columns
df.drop(["location","values"],axis=1,inplace=True)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644     NaN     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585     NaN     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
# 614     lp090    male     yes         3+       gradute           no
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
## how to delete the row
df.drop([614],inplace=True)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644     NaN     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 609  LP001640    Male     Yes          0      Graduate          Yes
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585     NaN     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
## to drop the missing values
## df.dropna()
df.dropna()
# Out:
#       Loan_ID  Gender Married Dependents Education Selfemployed  \
# 0    LP001722    Male     Yes          0  Graduate           No
# 3    LP002603  Female      No          0  Graduate           No
# 5    LP001259    Male     Yes          1  Graduate          Yes
# 6    LP002345    Male     Yes          0  Graduate           No
# 8    LP001030    Male     Yes          2  Graduate           No
# ..        ...     ...     ...        ...       ...          ...
# 607  LP001637    Male     Yes          1  Graduate           No
# 608  LP002422    Male      No          1  Graduate           No
# 609  LP001640    Male     Yes          0  Graduate          Yes
# 610  LP001536    Male     Yes         3+  Graduate           No
# 613  LP002317    Male     Yes         3+  Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644     NaN     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 609  LP001640    Male     Yes          0      Graduate          Yes
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585     NaN     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
## to find the missing values
## it will give null values is true remaining false
df.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Selfemployed  \
# 0      False   False    False       False      False         False
# 1      False   False    False       False      False          True
# 2      False   False    False       False      False          True
# 3      False   False    False       False      False         False
# 4      False    True    False       False      False         False
# ..       ...     ...      ...         ...        ...           ...
# 609    False   False    False       False      False         False
# 610    False   False    False       False      False         False
# 611    False    True    False       False      False         False
# 612    False   False    False       False      False          True
# 613    False   False    False       False      False         False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False       False             False
# ...

# %%
## to count the values

df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Selfemployed         32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
## you want to check column null values
df["Gender"].isnull().sum()
# Out:
# 13

# %%
### replace the null values with mode(or)mean(or)median
### first you need to check which data type it is..
df["Gender"].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
df['Gender']=df["Gender"].fillna(df['Gender'].mode()[0])

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644    Male     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 609  LP001640    Male     Yes          0      Graduate          Yes
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585    Male     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
df["Gender"].isnull().sum()
# Out:
# 0

# %%
df['LoanAmount'].isnull().sum()
# Out:
# 22

# %%
round(df['LoanAmount'].mean(
))
# Out:
# 146

# %%
import numpy as np
df["LoanAmount"]=np.where(df["LoanAmount"].isna(),df["LoanAmount"].mean(),df["LoanAmount"])

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644    Male     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 609  LP001640    Male     Yes          0      Graduate          Yes
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585    Male     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
df["LoanAmount"].isnull().sum()
# Out:
# 0

# %%
df["Loan_Amount_Term"].isnull().sum()
# Out:
# 14

# %%
df['Loan_Amount_Term'].describe()
# Out:
# count    600.00000
# mean     342.00000
# std       65.12041
# min       12.00000
# 25%      360.00000
# 50%      360.00000
# 75%      360.00000
# max      480.00000
# Name: Loan_Amount_Term, dtype: float64

# %%
df["Loan_Amount_Term"]=np.where(df["Loan_Amount_Term"].isna(),df["Loan_Amount_Term"].mean(),df["Loan_Amount_Term"])

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644    Male     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 609  LP001640    Male     Yes          0      Graduate          Yes
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585    Male     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
df["Loan_Amount_Term"].isnull().sum()
# Out:
# 0

# %%
df["ApplicantIncome"].describe()
# Out:
# count      614.000000
# mean      5403.459283
# std       6109.041673
# min        150.000000
# 25%       2877.500000
# 50%       3812.500000
# 75%       5795.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %%
### to identify the outlayers
q1=df["ApplicantIncome"].quantile(0.25)

# %%
q2=df["ApplicantIncome"].quantile(0.5)

# %%
q3=df["ApplicantIncome"].quantile(0.75
                              )

# %%
iqr=q3-q1

# %%
iqr
# Out:
# 2917.5

# %%
ll=q1-1.5*iqr
ll
# Out:
# -1498.75

# %%
ul=q3+1.5*iqr
ul
# Out:
# 10171.25

# %%
len(df[(df["ApplicantIncome"]<ll)|(df["ApplicantIncome"]>ul)])
# Out:
# 50

# %%
len(df[(df["ApplicantIncome"]>ll)&(df["ApplicantIncome"]<ul)])
# Out:
# 564

# %%
df[~((df["ApplicantIncome"]<ll)|(df["ApplicantIncome"]>ul))]
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644    Male     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 559  LP001519  Female      No          0      Graduate           No
# 560  LP001708  Female      No          0      Graduate           No
# 561  LP002050    Male     Yes          1      Graduate          Yes
# 562  LP002393  Female     NaN        NaN      Graduate           No
# 563  LP002795    Male     Yes         3+      Graduate          Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800  135.000000             360.0
# ...

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644    Male     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 609  LP001640    Male     Yes          0      Graduate          Yes
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585    Male     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
df.loc[(df["Married"]=="No")&(df["Dependents"].isna()),"Dependents"]=0

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate          NaN
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644    Male     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 609  LP001640    Male     Yes          0      Graduate          Yes
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585    Male     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
df["Dependents"].isnull().sum()
# Out:
# 11

# %%
df["Selfemployed"].isnull().sum()
# Out:
# 32

# %%
df.loc[(df["Education"]=="Not Graduate")&(df["Selfemployed"].isna()),"Selfemployed"]=df["Selfemployed"].mode()[0]

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Selfemployed  \
# 0    LP001722    Male     Yes          0      Graduate           No
# 1    LP002502  Female     Yes          2  Not Graduate           No
# 2    LP002949  Female      No         3+      Graduate          NaN
# 3    LP002603  Female      No          0      Graduate           No
# 4    LP001644    Male     Yes          0      Graduate          Yes
# ..        ...     ...     ...        ...           ...          ...
# 609  LP001640    Male     Yes          0      Graduate          Yes
# 610  LP001536    Male     Yes         3+      Graduate           No
# 611  LP001585    Male     Yes         3+      Graduate           No
# 612  LP002101    Male     Yes          0      Graduate          NaN
# 613  LP002317    Male     Yes         3+      Graduate           No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150               1800       135.0             360.0
# ...

# %%
df["Selfemployed"].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Selfemployed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
###find the averangeincome based on gender
df["ApplicantIncome"]=(df["Gender"]=="Male")["ApplicantIncome"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 ###find the averangeincome based on gender
# ----> 2 df["ApplicantIncome"]=(df["Gender"]=="Male")["ApplicantIncome"].mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# ...

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\mayaluri nani\Downloads\1940599-loandata - Copy\loandata.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
import numpy as np
df1=np.where(df["Married"]=="Male"),df["ApplicantIncome"].mean(),df["ApplicantIncome"]

# %%
### finding the average based on gender column
df[df["Gender"]=="c"]["ApplicantIncome"].mean()
# Out:
# 5446.460122699386

# %%
df[df["Gender"]=="Female"]["ApplicantIncome"].mean()
# Out:
# 4643.473214285715

# %%
df[df["Gender"].isna()]["ApplicantIncome"].mean()
# Out:
# 10333.538461538461

# %%
### finding the avrerage basedn on gender and married
df[(df["Gender"]=="Male")&(df['Married']=="No")]['ApplicantIncome'].mean()
# Out:
# 5236.1461538461535

# %%
df[(df["Gender"]=="Female")&(df['Married']=="Yes")]['ApplicantIncome'].mean()
# Out:
# 4829.645161290323

# %%
df["Gender"]=df['Gender'].fillna(df["Gender"].mode()[0])

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644    Male     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585    Male     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df["Gender"].isnull().sum()
# Out:
# 0

# %%
df[df["Education"]=="Graduate"]["CoapplicantIncome"].mean()
# Out:
# 1717.4748333096666

# %%
df[df["Education"]=="Not Graduate"]["CoapplicantIncome"].mean()
# Out:
# 1276.544776119403

# %%
df["Education"].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df[(df["Education"]=="Graduate")&(df["Self_Employed"]=="Yes")]["CoapplicantIncome"].mean()
# Out:
# 1657.676923076923

# %%
df["Education"]=df["Education"].fillna(df["Education"].mode()[0])

# %%
df["Education"].isnull().sum()
# Out:
# 0

# %%
df.groupby(by="Education").count()
# Out:
#               Loan_ID  Gender  Married  Dependents  Self_Employed  \
# Education
# Graduate          480     480      477         469            454
# Not Graduate      134     134      134         130            128
#
#               ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Education
# Graduate                  480                480         465
# Not Graduate              134                134         127
#
#               Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# Education
# Graduate                   472             443            480          480
# Not Graduate               128             121            134          134

# %%
df["Married"].isnull().sum()
# Out:
# 3

# %%
df.groupby(by="Married").count()
# Out:
#          Loan_ID  Gender  Dependents  Education  Self_Employed  \
# Married
# No           213     213         209        213            199
# Yes          398     398         390        398            380
#
#          ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Married
# No                   213                213         206               208
# Yes                  398                398         384               389
#
#          Credit_History  Property_Area  Loan_Status
# Married
# No                  199            213          213
# Yes                 362            398          398

# %%
df.groupby(by=["Married","Gender"])["ApplicantIncome"].mean()
# Out:
# Married  Gender
# No       Female    4503.787500
#          Male      5251.045113
# Yes      Female    4829.645161
#          Male      5696.708447
# Name: ApplicantIncome, dtype: float64

# %%
df.groupby(by="ApplicantIncome")["Married"].mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
df.groupby(by="Gender")["ApplicantIncome"].agg(["mean","median","max","min"])
# Out:
#                mean  median    max  min
# Gender
# Female  4643.473214  3583.0  19484  210
# Male    5573.017928  3862.0  81000  150

# %%
df.groupby(by="Gender")["ApplicantIncome"].describe()
# Out:
#         count         mean          std    min     25%     50%     75%  \
# Gender
# Female  112.0  4643.473214  3585.381488  210.0  2661.5  3583.0  4606.5
# Male    502.0  5573.017928  6531.266299  150.0  2900.5  3862.0  5939.5
#
#             max
# Gender
# Female  19484.0
# Male    81000.0

# %%
pd.pivot_table(data = df,index=["Gender",'Education'],columns='Married',values=['ApplicantIncome','CoapplicantIncome'],aggfunc='max')
# Out:
#                     ApplicantIncome        CoapplicantIncome
# Married                          No    Yes                No      Yes
# Gender Education
# Female Graduate               15759  19484           41667.0   4486.0
#        Not Graduate           18165   7142            2365.0   3237.0
# Male   Graduate               37719  81000           33837.0  20000.0
#        Not Graduate            7333   7667            2785.0   7101.0

# %%
df.pivot_table(index="Gender",columns="Married",values=["ApplicantIncome"],aggfunc=(["max","min"]))
# Out:
#                     max                    min
#         ApplicantIncome        ApplicantIncome
# Married              No    Yes              No  Yes
# Gender
# Female            18165  19484             416  210
# Male              37719  81000            1442  150

# %%
df.groupby(by=["Married","Education"])[["ApplicantIncome","CoapplicantIncome"]].agg(["mean","median"])
# Out:
#                      ApplicantIncome         CoapplicantIncome
#                                 mean  median              mean  median
# Married Education
# No      Graduate         5174.476190  3829.5       1466.339286     0.0
#         Not Graduate     4208.444444  3596.0        757.377778     0.0
# Yes     Graduate         6225.355987  4106.0       1868.248932  1667.0
#         Not Graduate     3559.280899  3333.0       1539.044944  1587.0

# %%
df.pivot_table(index="Married",columns="Education",values=["ApplicantIncome"],aggfunc=["max","min","mean"])
# Out:
#                       max                          min               \
#           ApplicantIncome              ApplicantIncome
# Education        Graduate Not Graduate        Graduate Not Graduate
# Married
# No                  37719        18165             416         1442
# Yes                 81000         7667             150          210
#
#                      mean
#           ApplicantIncome
# Education        Graduate Not Graduate
# Married
# No            5174.476190  4208.444444
# Yes           6225.355987  3559.280899

# %%
df[(df["Married"]=="Yes")&(df["Ma"]=="Graduate")]["CoapplicantIncome"].mean()
# Out:
# 1868.2489320020711

# %%
pd.crosstab(index=df["Married"],columns=df["Gender"])
# Out:
# Gender   Female  Male
# Married
# No           80   133
# Yes          31   367

# %%
df.groupby(by="Married")["CoapplicantIncome"].agg(["mean","median"])
# Out:
#                 mean  median
# Married
# No       1316.558685     0.0
# Yes      1794.632965  1625.0

# %%
df.pivot_table(index="Married",columns="Gender",values=["CoapplicantIncome"],aggfunc=["mean","median"])
# Out:
#                      mean                         median
#         CoapplicantIncome              CoapplicantIncome
# Gender             Female         Male            Female    Male
# Married
# No             1020.01250  1494.932331               0.0     0.0
# Yes            1370.83871  1830.430300            1459.0  1625.0

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644    Male     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585    Male     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df[df['Gender']=="Male"]["CoapplicantIncome"].mean()
# Out:
# 1735.7528286626296

# %%
df.groupby(by="Gender")["CoapplicantIncome"].mean()
# Out:
# Gender
# Female    1108.008929
# Male      1735.752829
# Name: CoapplicantIncome, dtype: float64

# %%
df.groupby(by=["Gender","Married"])["CoapplicantIncome"].agg(["mean","median"])
# Out:
#                        mean  median
# Gender Married
# Female No       1020.012500     0.0
#        Yes      1370.838710  1459.0
# Male   No       1494.932331     0.0
#        Yes      1830.430300  1625.0

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df["Gender"]=df["Gender"].fillna(df["Gender"].mode()[0])

# %%
df["Gender"].isnull().sum()
# Out:
# 0

# %%
## change the gender the coulumn values male is 1 and replace 0 with the help of apply function
def change_colname(x):
    if df["Gender"]=="Male":
        return 1
    else:
        return 0

# %%
change_colname('Male')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9992\1288180740.py in ?()
# ----> 1 change_colname('Male')
#
# ~\AppData\Local\Temp\ipykernel_9992\2808243721.py in ?(x)
#       2 def change_colname(x):
# ----> 3     if df["Gender"]=="Male":
#       4         return 1
#       5     else:
#       6         return 0
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1469         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
### change the gender values column values male is 1 and replace 0
import numpy as np
df["Gender"]=np.where(df["Gender"]=="Male",1,0)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722       1     Yes          0      Graduate            No
# 1    LP002502       0     Yes          2  Not Graduate           NaN
# 2    LP002949       0      No         3+      Graduate           NaN
# 3    LP002603       0      No          0      Graduate            No
# 4    LP001644       1     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640       1     Yes          0      Graduate           Yes
# 610  LP001536       1     Yes         3+      Graduate            No
# 611  LP001585       1     Yes         3+      Graduate            No
# 612  LP002101       1     Yes          0      Graduate           NaN
# 613  LP002317       1     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df["Gender"].apply(lambda x:1 if x=="Male" else 0)
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 609    1
# 610    1
# 611    0
# 612    1
# 613    1
# Name: Gender, Length: 614, dtype: int64

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
def change_income(x):
    if x<5000:
        return "low"
    elif x>5000 and x<10000:
        return "medium"
    else:
        return "high"

# %%
df["ApplicantIncome"]=df["ApplicantIncome"].apply(change_income)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df["ApplicantIncome"].isnull().sum()
# Out:
# 0
